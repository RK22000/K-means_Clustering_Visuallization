# %%
# %matplotlib widget
import vis
import numpy as np
import matplotlib.pyplot as plt

try:
    anime.event_source.stop()
    plt.cla()
except NameError:
    pass

configuration = {
    # "seed": np.random.randint(100000),
    "seed": 73763,
    "act_centers": 7,
    "num_centers": 7, # Don't exceed 8 cuz I only put in 8 colors
    "iters": 100,
    "jitters": 1,
    "save_file": "Cool.mp4" # Put file name if you wish to save as video
}

print(f"Using config {configuration}")

# plt.rcParams["animation.html"] = "jshtml"
# plt.rcParams['figure.dpi'] = 150  
# plt.ioff()

anime = vis.run_visualization(configuration)
plt.show()
# Out:
# Using config {'seed': 73763, 'act_centers': 7, 'num_centers': 7, 'iters': 100, 'jitters': 1, 'save_file': 'Cool.mp4'}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
anime.event_source.stop()
